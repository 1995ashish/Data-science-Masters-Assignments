# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %% [raw]
# Answer: Matplotlib is a plotting library for the Python programming language and its numerical mathematics extension NumPy. it is used for creating static, animated, and interactive visualizations in Python.
#
# The five plots that can be plotted using the Pyplot module of Matplotlib are:
#
# *Line plot.
# *Histogram.
# *Bar Chart.
# *Scatter plot.
# *Pie charts.

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.

# %% [raw]
# import numpy as np
# np.random.seed(3)
# x = 3 + np.random.normal(0, 2, 50)
# y = 3 + np.random.normal(0, 2, len(x))
# Note: Also add title, xlabel, and ylabel to the plot.

# %% [raw]
# Answer: A scatter plot (aka scatter chart, scatter graph) uses dots to represent values for two different numeric variables. The position of each dot on the horizontal and vertical axis indicates values for an individual data point. Scatter plots are used to observe relationships between variables.

# %%
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# %%
x
# Out:
# array([ 6.57725695,  3.8730197 ,  3.19299494, -0.72698541,  2.44522359,
#         2.29048204,  2.83451704,  1.74599865,  2.91236366,  2.04556394,
#         0.37227049,  4.76924476,  4.76263608,  6.41914613,  3.10006728,
#         2.19064517,  1.9092801 , -0.09295463,  4.96473487,  0.79786474,
#         0.62990695,  2.5887002 ,  5.97229671,  3.47343253,  0.95242972,
#         1.5740136 ,  4.25048993,  2.67897327,  1.4623273 ,  2.53993856,
#         4.49011253,  6.95222157,  0.51175334,  1.74716618,  1.39246781,
#        -1.83816635,  1.15241596,  0.95224848,  5.24795592,  2.73617153,
#        -0.24657089,  4.2933509 ,  2.28745848, -0.48628207,  1.80670072,
#         1.82281124,  1.2522354 ,  3.05942763, -1.49651554,  2.46447627])

# %%
y
# Out:
# array([ 5.02636688,  4.70559568,  5.216375  ,  5.23878131,  5.97508626,
#         0.76339863,  4.69166681, -0.72177906,  1.79422979, -0.82894409,
#         5.09629502,  5.66747564,  2.60517064,  6.54929006,  1.65054498,
#         3.30123373,  3.30589141,  0.87160945,  3.87589322,  6.87795692,
#         0.95013825,  4.79867689,  2.6909863 ,  6.53925461,  3.9675767 ,
#         4.3524328 ,  4.28632656,  3.49817341,  0.20847299,  5.78332582,
#         0.25866197,  3.47712638,  4.22815418,  1.32417545,  3.29012643,
#         5.33576457,  2.95179106,  1.22268516, -2.8314755 ,  1.05631899,
#         1.81784252,  1.96716526,  1.08000764,  3.75459047,  1.85058316,
#         2.78109133,  4.3581432 ,  1.28912566,  2.39958785,  7.31629868])

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.xlabel("This is Xlevel")
plt.ylabel("This is Xlevel")
plt.title("This is title to the plot")
# Out:
# Text(0.5, 1.0, 'This is title to the plot')

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.

# %% [raw]
# Use the following data:
# import numpy as np
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %% [raw]
# Answer: subplot() function adds subplot to a current figure at the specified grid position. It is similar to the subplots() function however unlike subplots() it adds one subplot at a time. So to create multiple plots you will need several lines of code with the subplot() functio

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([0, 100, 200, 300, 400, 500])

# %%
plt.subplot(1, 2, 1)
plt.plot(x,y)

# %%
x1 = np.array([0, 1, 2, 3, 4, 5]) 
y1=np.array([50, 20, 40, 20, 60, 70])
plt.subplot(1,1,1)
plt.plot(x1,y1)

# %%
plt.subplot(1,1,1)
x2 = np.array([0, 1, 2, 3, 4, 5]) 
y2=np.array([10, 20, 30, 40, 50, 60])
plt.plot(x2,y2)

# %%
plt.subplot(1,1,1)
x3 = np.array([0, 1, 2, 3, 4, 5]) 
y3=np.array([200, 350, 250, 550, 450, 150])
plt.plot(x3,y3)

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.

# %% [raw]
# import numpy as np
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
# profit = np.array([3000, 8000, 1000, 10000])

# %% [raw]
# Answer: A bar plot or bar chart is a graph that represents the category of data with rectangular bars with lengths and heights that is proportional to the values which they represent. The bar plots can be plotted horizontally or vertically. A bar chart describes the comparisons between the discrete categories. One of the axis of the plot represents the specific categories being compared, while the other axis represents the measured values corresponding to those categories.

# %%
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %%
plt.bar(company,profit,color='r')
plt.grid()

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.

# %% [raw]
# box1 = np.random.normal(100, 10, 200)
# box2 = np.random.normal(90, 20, 200)

# %% [raw]
# Answer: A box plot which is also known as a whisker plot displays a summary of a set of data containing the minimum, first quartile, median, third quartile, and maximum. In a box plot, we draw a box from the first quartile to the third quartile. A vertical line goes through the box at the median

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# %%
plt.boxplot(box1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fbf19fc8490>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fbf1a0a6d40>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fbf19fc93f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fbf19e05750>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fbf19e07e50>],
#  'means': []}

# %%
plt.boxplot(box2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fbf19ee3e20>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fbf19d083a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fbf19ee3b80>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fbf19d088e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fbf19d08b80>],
#  'means': []}
